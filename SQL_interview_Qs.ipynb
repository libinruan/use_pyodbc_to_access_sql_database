# %% [markdown]
# # Support for SQL server via PyODBC package

# %% [markdown]
# ## Adventure Works database

# %%
import pyodbc

# the parameter you need to manually input
config = dict(server=   'localhost', # change this to your SQL Server hostname or IP address
               port=      1433,       # change this to your SQL Server port number [1433 is the default]
               database= 'AdventureWorks', 
               username= 'tanya',     # set up the username and password for connection by using Microsoft SQL Server Managerment Studio
               password= 'Tanya1234') 

# connection boiler plate
conn_str = ('SERVER={server},{port};'   +
             'DATABASE={database};'     +
             'UID={username};'          +
             'PWD={password}')
conn = pyodbc.connect(
     r'DRIVER={ODBC Driver 13 for SQL Server};' + #this is the only item you may change
     conn_str.format(**config)
     )

# initiate the connection to SQL database
cursor = conn.cursor()
cursor.execute('SELECT * FROM dbo.AWBuildVersion;')

# list all the data 
for entry in cursor:
    print(entry)
    
conn.close
# Out:
# (1, '14.0.1000.169', datetime.datetime(2017, 8, 22, 19, 39, 35, 643000), datetime.datetime(2017, 10, 27, 14, 33, 2, 347000))
# <function Connection.close>

# %% [markdown]
# ## Northwind databas

# %%
 import pyodbc
 config = dict(server=   'localhost', # change this to your SQL Server hostname or IP address
               port=      1433,       # change this to your SQL Server port number [1433 is the default]
               database= 'NorthWind',
               username= 'sa',         # use administor's default username: sa
               password= '1234')       # use administor's password. Set it in Microsoft SSMS.
 conn_str = ('SERVER={server},{port};'   +
             'DATABASE={database};'     +
             'UID={username};'          +
             'PWD={password}')
 conn = pyodbc.connect(
     r'DRIVER={ODBC Driver 13 for SQL Server};' +
     conn_str.format(**config)
     )
 cursor = conn.cursor()
 cursor.execute('SELECT * FROM dbo.Orders;')
 for entry in cursor:
     pass
     # print(entry) # Comment out for saving space in Jupyter notebook
 conn.close
# Out:
# <function Connection.close>

# %% [markdown]
# # Connect SQL Server 2017 via its ODBC drivers

# %% [markdown]
# Method 1. use SQLAlchemy package

# %%
engine = create_engine("mssql+pyodbc://sa:1234@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC+Driver+13+for+SQL+Server")

# %% [markdown]
# Method 2. use SQL magic function

# %%
## if you have not loaded sql, type "load_ext sql"

# %reload_ext sql 
# %sql mssql+pyodbc://sa:1234@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC+Driver+13+for+SQL+Server
# %sql select * from orders

# %% [markdown]
# # Preliminary
# - Show all the tables in our database
# - Show all the columns in a table
# - Show all the levels/categories in a column (a.k.a. field)

# %% [markdown]
# ## P1. Show all the tables our db contains

# %% [markdown]
# ### Method 1.

# %%
import pandas as pd
from pandas import Series
from sqlalchemy import create_engine
# engine = create_engine('sqlite:///Northwind.sqlite')
engine = create_engine('mssql+pyodbc://sa:isyegatech@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC+Driver+13+for+SQL+Server')
Series(engine.table_names())
# Out:
# 0               Categories
# 1     CustomerCustomerDemo
# 2     CustomerDemographics
# 3                Customers
# 4                Employees
# 5      EmployeeTerritories
# 6            Order Details
# 7                   Orders
# 8                 Products
# 9                   Region
# 10                Shippers
# 11               Suppliers
# 12             sysdiagrams
# 13             Territories
# dtype: object

# %% [markdown]
# ### Method 2. Use SQL with the connection string suggested by SQLALchemy (Better)

# %%
# %load_ext sql 
# %sql mssql+pyodbc://sa:1234@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC+Driver+13+for+SQL+Server
result = %sql SELECT * FROM NorthWind.INFORMATION_SCHEMA.TABLES --we can assign the result to a temp variable
print(result)
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# +---------------+--------------+--------------------------------+------------+
# | TABLE_CATALOG | TABLE_SCHEMA |           TABLE_NAME           | TABLE_TYPE |
# +---------------+--------------+--------------------------------+------------+
# |   NorthWind   |     dbo      |             Orders             | BASE TABLE |
# |   NorthWind   |     dbo      |            Products            | BASE TABLE |
# |   NorthWind   |     dbo      |         Order Details          | BASE TABLE |
# |   NorthWind   |     dbo      | Customer and Suppliers by City |    VIEW    |
# |   NorthWind   |     dbo      | Alphabetical list of products  |    VIEW    |
# ...

# %%
# Otherwise, let the result shown directly after the magic function
# %sql SELECT * FROM NorthWind.INFORMATION_SCHEMA.TABLES --we can assign the result to a temp variable
# Out:
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('NorthWind', 'dbo', 'Orders', 'BASE TABLE'),
#  ('NorthWind', 'dbo', 'Products', 'BASE TABLE'),
#  ('NorthWind', 'dbo', 'Order Details', 'BASE TABLE'),
#  ('NorthWind', 'dbo', 'Customer and Suppliers by City', 'VIEW'),
#  ('NorthWind', 'dbo', 'Alphabetical list of products', 'VIEW'),
#  ('NorthWind', 'dbo', 'Current Product List', 'VIEW'),
#  ('NorthWind', 'dbo', 'Orders Qry', 'VIEW'),
#  ('NorthWind', 'dbo', 'Products Above Average Price', 'VIEW'),
#  ('NorthWind', 'dbo', 'Products by Category', 'VIEW'),
#  ('NorthWind', 'dbo', 'Quarterly Orders', 'VIEW'),
#  ('NorthWind', 'dbo', 'Invoices', 'VIEW'),
#  ('NorthWind', 'dbo', 'Order Details Extended', 'VIEW'),
#  ('NorthWind', 'dbo', 'Order Subtotals', 'VIEW'),
#  ('NorthWind', 'dbo', 'Product Sales for 1997', 'VIEW'),
# ...

# %% [markdown]
# ## P2. Show all the column names of our table

# %%
# use either load_ext sql or reload_ext sql
# %sql sqlite:///Northwind_small.sqlite

# %%
# %reload_ext sql 
# %sql mssql+pyodbc://sa:1234@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC+Driver+13+for+SQL+Server
# %sql SELECT * FROM NorthWind.INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'Order Details'
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('NorthWind', 'dbo', 'Order Details', 'OrderID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Order Details', 'ProductID', 2, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Order Details', 'UnitPrice', 3, '(0)', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Order Details', 'Quantity', 4, '(1)', 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Order Details', 'Discount', 5, '(0)', 'NO', 'real', None, None, 24, 2, None, None, None, None, None, None, None, None, None, None, None)]

# %% [markdown]
# ## P3. Show all the values in a column

# %%
import sqlite3
conn = sqlite3.connect('')
cursor = sqlite3.connect('Northwind_small.sqlite').cursor()
# cursor = sqlite3.connect("mssql+pyodbc://sa:1234@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC+Driver+13+for+SQL+Server").cursor()
jobs = [job[0] for job in cursor.execute("SELECT Country FROM Employee")]
print(set(jobs))
cursor.close()
# Out:
# {'UK', 'USA'}

# %% [markdown]
# # Questions

# %%
# Be sure to use it under TensorFlow-GPU 
# Otherwise, you need to install ipython-sql
# %load_ext sql

# %%
# %sql mssql+pyodbc://sa:1234@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC+Driver+13+for+SQL+Server
# Out:
# 'Connected: sa@NorthWind'

# %% [markdown]
# ## M01. What shippers do we have?

# %% [markdown]
# From P1, we konw we have 14 tables in the Northwind_small database. <br>
# Now the first question is "Show all the columns in the Shippers table."

# %%
# %%sql
# SELECT * FROM Shippers;
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(1, 'Speedy Express', '(503) 555-9831'),
#  (2, 'United Package', '(503) 555-3199'),
#  (3, 'Federal Shipping', '(503) 555-9931')]

# %% [markdown]
# ## M02. Show only two columns, CategoryName and Description, in the Categories table.

# %%
# %%sql
# SELECT * FROM INFORMATION_SCHEMA.Columns WHERE TABLE_NAME='Categories'
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('NorthWind', 'dbo', 'Categories', 'CategoryID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Categories', 'CategoryName', 2, None, 'NO', 'nvarchar', 15, 30, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('NorthWind', 'dbo', 'Categories', 'Description', 3, None, 'YES', 'ntext', 1073741823, 2147483646, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('NorthWind', 'dbo', 'Categories', 'Picture', 4, None, 'YES', 'image', 2147483647, 2147483647, None, None, None, None, None, None, None, None, None, None, None, None, None)]

# %%
# %%sql
# SELECT CategoryID, CategoryName, Description FROM Categories;
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(1, 'lol', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (3, 'Confections', 'Desserts, candies, and sweet breads'),
#  (4, 'Dairy Products', 'Cheeses'),
#  (5, 'Grains/Cereals', 'Breads, crackers, pasta, and cereal'),
#  (6, 'Meat/Poultry', 'Prepared meats'),
#  (7, 'Produce', 'Dried fruit and bean curd'),
#  (8, 'Seafood', 'Seaweed and fish')]

# %% [markdown]
# ## M03. Show the sales representatives roster in the Employee table.

# %% [markdown]
# Show full names and hire dates for every sales representative.

# %%
# %%sql
# SELECT FirstName, LastName, Title, HireDate FROM Employees;
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Nancy', 'Davolio', 'Sales Representative', datetime.datetime(1992, 5, 1, 0, 0)),
#  ('Andrew', 'Fuller', 'Vice President, Sales', datetime.datetime(1992, 8, 14, 0, 0)),
#  ('Janet', 'Leverling', 'Sales Representative', datetime.datetime(1992, 4, 1, 0, 0)),
#  ('Margaret', 'Peacock', 'Sales Representative', datetime.datetime(1993, 5, 3, 0, 0)),
#  ('Steven', 'Buchanan', 'Sales Manager', datetime.datetime(1993, 10, 17, 0, 0)),
#  ('Michael', 'Suyama', 'Sales Representative', datetime.datetime(1993, 10, 17, 0, 0)),
#  ('Robert', 'King', 'Sales Representative', datetime.datetime(1994, 1, 2, 0, 0)),
#  ('Laura', 'Callahan', 'Inside Sales Coordinator', datetime.datetime(1994, 3, 5, 0, 0)),
#  ('Anne', 'Dodsworth', 'Sales Representative', datetime.datetime(1994, 11, 15, 0, 0))]

# %% [markdown]
# **Don't** use double quotation!

# %%
# %%sql
# SELECT FirstName, LastName, Title, HireDate, Country FROM Employees WHERE Title='Sales Representative';
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Nancy', 'Davolio', 'Sales Representative', datetime.datetime(1992, 5, 1, 0, 0), 'USA'),
#  ('Janet', 'Leverling', 'Sales Representative', datetime.datetime(1992, 4, 1, 0, 0), 'USA'),
#  ('Margaret', 'Peacock', 'Sales Representative', datetime.datetime(1993, 5, 3, 0, 0), 'USA'),
#  ('Michael', 'Suyama', 'Sales Representative', datetime.datetime(1993, 10, 17, 0, 0), 'UK'),
#  ('Robert', 'King', 'Sales Representative', datetime.datetime(1994, 1, 2, 0, 0), 'UK'),
#  ('Anne', 'Dodsworth', 'Sales Representative', datetime.datetime(1994, 11, 15, 0, 0), 'UK')]

# %% [markdown]
# ## M04. (from M03) Sales representatives in the US

# %%
# %%sql
# SELECT FirstName, LastName, HireDate, Country
# FROM Employees
# WHERE Title='Sales Representative' and Country='USA';
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Nancy', 'Davolio', datetime.datetime(1992, 5, 1, 0, 0), 'USA'),
#  ('Janet', 'Leverling', datetime.datetime(1992, 4, 1, 0, 0), 'USA'),
#  ('Margaret', 'Peacock', datetime.datetime(1993, 5, 3, 0, 0), 'USA')]

# %% [markdown]
# ## M05. Show orders placed by someone

# %%
# %%sql
# SELECT *
# FROM Northwind.INFORMATION_SCHEMA.COLUMNS
# WHERE TABLE_NAME = N'Orders'
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('NorthWind', 'dbo', 'Orders', 'OrderID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Orders', 'CustomerID', 2, None, 'YES', 'nchar', 5, 10, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('NorthWind', 'dbo', 'Orders', 'EmployeeID', 3, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Orders', 'OrderDate', 4, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Orders', 'RequiredDate', 5, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
# ...

# %%
# %%sql
# SELECT OrderID, OrderDate FROM Orders
# WHERE EmployeeID=5
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
#    sqlite:///Northwind_small.sqlite
# Done.
# [(10248, datetime.datetime(1996, 7, 4, 0, 0)),
#  (10254, datetime.datetime(1996, 7, 11, 0, 0)),
#  (10269, datetime.datetime(1996, 7, 31, 0, 0)),
#  (10297, datetime.datetime(1996, 9, 4, 0, 0)),
#  (10320, datetime.datetime(1996, 10, 3, 0, 0)),
#  (10333, datetime.datetime(1996, 10, 18, 0, 0)),
#  (10358, datetime.datetime(1996, 11, 20, 0, 0)),
#  (10359, datetime.datetime(1996, 11, 21, 0, 0)),
#  (10372, datetime.datetime(1996, 12, 4, 0, 0)),
#  (10378, datetime.datetime(1996, 12, 10, 0, 0)),
#  (10397, datetime.datetime(1996, 12, 27, 0, 0)),
#  (10463, datetime.datetime(1997, 3, 4, 0, 0)),
#  (10474, datetime.datetime(1997, 3, 13, 0, 0)),
#  (10477, datetime.datetime(1997, 3, 17, 0, 0)),
#  (10529, datetime.datetime(1997, 5, 7, 0, 0)),
#  (10549, datetime.datetime(1997, 5, 27, 0, 0)),
#  (10569, datetime.datetime(1997, 6, 16, 0, 0)),
# ...

# %% [markdown]
# ## M06. Logic Operators
# In Table Suppliers, show the attribute list of people not Marketing Manager. The attributes include the SupplierID, ContacName, and ContactTitle.

# %%
# %%sql
# SELECT SupplierID, ContactName, ContactTitle
# FROM Suppliers
# WHERE ContactTitle <> 'Marketing Manager'
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(1, 'Charlotte Cooper', 'Purchasing Manager'),
#  (2, 'Shelley Burke', 'Order Administrator'),
#  (3, 'Regina Murphy', 'Sales Representative'),
#  (5, 'Antonio del Valle Saavedra', 'Export Administrator'),
#  (6, 'Mayumi Ohno', 'Marketing Representative'),
#  (8, 'Peter Wilson', 'Sales Representative'),
#  (9, 'Lars Peterson', 'Sales Agent'),
#  (11, 'Petra Winkler', 'Sales Manager'),
#  (12, 'Martin Bein', 'International Marketing Mgr.'),
#  (13, 'Sven Petersen', 'Coordinator Foreign Markets'),
#  (14, 'Elio Rossi', 'Sales Representative'),
#  (16, 'Cheryl Saylor', 'Regional Account Rep.'),
#  (17, 'Michael Björn', 'Sales Representative'),
#  (18, 'Guylène Nodier', 'Sales Manager'),
#  (19, 'Robb Merchant', 'Wholesale Account Agent'),
#  (20, 'Chandra Leka', 'Owner'),
#  (21, 'Niels Petersen', 'Sales Manager'),
#  (22, 'Dirk Luchte', 'Accounting Manager'),
# ...

# %%
# %%sql
# SELECT SupplierID, ContactName, ContactTitle
# FROM Suppliers
# WHERE ContactTitle != 'Marketing Manager'
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(1, 'Charlotte Cooper', 'Purchasing Manager'),
#  (2, 'Shelley Burke', 'Order Administrator'),
#  (3, 'Regina Murphy', 'Sales Representative'),
#  (5, 'Antonio del Valle Saavedra', 'Export Administrator'),
#  (6, 'Mayumi Ohno', 'Marketing Representative'),
#  (8, 'Peter Wilson', 'Sales Representative'),
#  (9, 'Lars Peterson', 'Sales Agent'),
#  (11, 'Petra Winkler', 'Sales Manager'),
#  (12, 'Martin Bein', 'International Marketing Mgr.'),
#  (13, 'Sven Petersen', 'Coordinator Foreign Markets'),
#  (14, 'Elio Rossi', 'Sales Representative'),
#  (16, 'Cheryl Saylor', 'Regional Account Rep.'),
#  (17, 'Michael Björn', 'Sales Representative'),
#  (18, 'Guylène Nodier', 'Sales Manager'),
#  (19, 'Robb Merchant', 'Wholesale Account Agent'),
#  (20, 'Chandra Leka', 'Owner'),
#  (21, 'Niels Petersen', 'Sales Manager'),
#  (22, 'Dirk Luchte', 'Accounting Manager'),
# ...

# %% [markdown]
# ## M07. String Matching
# In Table Products, show the attributes of products whose name includes the string "queso". The attributes include their IDs and Names.

# %%
# %%sql
# SELECT ProductID, ProductName
# FROM Products
# WHERE ProductName LIKE '%queso%'
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(11, 'Queso Cabrales'), (12, 'Queso Manchego La Pastora')]

# %% [markdown]
# ## M08. Logical Operators
# In Table Orders, show the attribute of orders which come from either France or Belgium (@ShipCountry). The attributes include the OrderID, CustomerID, and ShipCountry.

# %%
# %%sql
# SELECT OrderID, CustomerID, ShipCountry
# FROM Orders
# WHERE ShipCountry='France' or ShipCountry='Belgium'
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(10248, 'VINET', 'France'),
#  (10251, 'VICTE', 'France'),
#  (10252, 'SUPRD', 'Belgium'),
#  (10265, 'BLONP', 'France'),
#  (10274, 'VINET', 'France'),
#  (10295, 'VINET', 'France'),
#  (10297, 'BLONP', 'France'),
#  (10302, 'SUPRD', 'Belgium'),
#  (10311, 'DUMON', 'France'),
#  (10331, 'BONAP', 'France'),
#  (10334, 'VICTE', 'France'),
#  (10340, 'BONAP', 'France'),
#  (10350, 'LAMAI', 'France'),
#  (10358, 'LAMAI', 'France'),
#  (10360, 'BLONP', 'France'),
#  (10362, 'BONAP', 'France'),
#  (10371, 'LAMAI', 'France'),
#  (10408, 'FOLIG', 'France'),
#  (10413, 'LAMAI', 'France'),
#  (10425, 'LAMAI', 'France'),
#  (10436, 'BLONP', 'France'),
#  (10449, 'BLONP', 'France'),
#  (10450, 'VICTE', 'France'),
#  (10454, 'LAMAI', 'France'),
#  (10458, 'SUPRD', 'Belgium'),
#  (10459, 'VICTE', 'France'),
#  (10463, 'SUPRD', 'Belgium'),
#  (10470, 'BONAP', 'France'),
# ...

# %% [markdown]
# ## M09. True if in a set

# %%
# %%sql
# SELECT TOP 10 OrderID, CustomerID, ShipCountry
# FROM Orders
# WHERE ShipCountry IN ('Brazil', 'Mexico', 'Argentina', 'Venezuela')
# Out:
# UsageError: Cell magic `%%sql` not found.

# %% [markdown]
# ## M10. Sorting

# %% [markdown]
# SQL is case insensitive.

# %%
# %%sql
# SELECT FirstName, LastName, Title, BirthDate
# FROM Employees
# ORDER BY BirthDate
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Margaret', 'Peacock', 'Sales Representative', datetime.datetime(1937, 9, 19, 0, 0)),
#  ('Nancy', 'Davolio', 'Sales Representative', datetime.datetime(1948, 12, 8, 0, 0)),
#  ('Andrew', 'Fuller', 'Vice President, Sales', datetime.datetime(1952, 2, 19, 0, 0)),
#  ('Steven', 'Buchanan', 'Sales Manager', datetime.datetime(1955, 3, 4, 0, 0)),
#  ('Laura', 'Callahan', 'Inside Sales Coordinator', datetime.datetime(1958, 1, 9, 0, 0)),
#  ('Robert', 'King', 'Sales Representative', datetime.datetime(1960, 5, 29, 0, 0)),
#  ('Michael', 'Suyama', 'Sales Representative', datetime.datetime(1963, 7, 2, 0, 0)),
#  ('Janet', 'Leverling', 'Sales Representative', datetime.datetime(1963, 8, 30, 0, 0)),
#  ('Anne', 'Dodsworth', 'Sales Representative', datetime.datetime(1966, 1, 27, 0, 0))]

# %% [markdown]
# ## M11. Datetime conversion

# %%
# %%sql
# SELECT FirstName, LastName, Title, DateOnlyBirthDate=CONVERT(DATE,BirthDate)
# FROM Employees
# ORDER BY BirthDate
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Margaret', 'Peacock', 'Sales Representative', datetime.date(1937, 9, 19)),
#  ('Nancy', 'Davolio', 'Sales Representative', datetime.date(1948, 12, 8)),
#  ('Andrew', 'Fuller', 'Vice President, Sales', datetime.date(1952, 2, 19)),
#  ('Steven', 'Buchanan', 'Sales Manager', datetime.date(1955, 3, 4)),
#  ('Laura', 'Callahan', 'Inside Sales Coordinator', datetime.date(1958, 1, 9)),
#  ('Robert', 'King', 'Sales Representative', datetime.date(1960, 5, 29)),
#  ('Michael', 'Suyama', 'Sales Representative', datetime.date(1963, 7, 2)),
#  ('Janet', 'Leverling', 'Sales Representative', datetime.date(1963, 8, 30)),
#  ('Anne', 'Dodsworth', 'Sales Representative', datetime.date(1966, 1, 27))]

# %% [markdown]
# ## M12. String concatenation

# %%
# %%sql
# SELECT FirstName, LastName, FullName= FirstName + ' ' + LastName
# FROM Employees
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Nancy', 'Davolio', 'Nancy Davolio'),
#  ('Andrew', 'Fuller', 'Andrew Fuller'),
#  ('Janet', 'Leverling', 'Janet Leverling'),
#  ('Margaret', 'Peacock', 'Margaret Peacock'),
#  ('Steven', 'Buchanan', 'Steven Buchanan'),
#  ('Michael', 'Suyama', 'Michael Suyama'),
#  ('Robert', 'King', 'Robert King'),
#  ('Laura', 'Callahan', 'Laura Callahan'),
#  ('Anne', 'Dodsworth', 'Anne Dodsworth')]

# %%
# %%sql
# SELECT FirstName, LastName, FullName= CONCAT(FirstName, ' ', LastName)
# FROM Employees
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Nancy', 'Davolio', 'Nancy Davolio'),
#  ('Andrew', 'Fuller', 'Andrew Fuller'),
#  ('Janet', 'Leverling', 'Janet Leverling'),
#  ('Margaret', 'Peacock', 'Margaret Peacock'),
#  ('Steven', 'Buchanan', 'Steven Buchanan'),
#  ('Michael', 'Suyama', 'Michael Suyama'),
#  ('Robert', 'King', 'Robert King'),
#  ('Laura', 'Callahan', 'Laura Callahan'),
#  ('Anne', 'Dodsworth', 'Anne Dodsworth')]

# %% [markdown]
# ## M13. Arithmetic Operators

# %%
# %%sql
# SELECT *
# FROM INFORMATION_SCHEMA.COLUMNS
# WHERE TABLE_NAME='Order' + ' ' + 'Details'
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('NorthWind', 'dbo', 'Order Details', 'OrderID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Order Details', 'ProductID', 2, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Order Details', 'UnitPrice', 3, '(0)', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Order Details', 'Quantity', 4, '(1)', 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Order Details', 'Discount', 5, '(0)', 'NO', 'real', None, None, 24, 2, None, None, None, None, None, None, None, None, None, None, None)]

# %%
# %%sql
# SELECT OrderID, ProductID, UnitPrice, Quantity, TotalPrice = UnitPrice * Quantity
# FROM "Order Details"
# ORDER BY OrderID, ProductID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(10248, 11, Decimal('14.0000'), 12, Decimal('168.0000')),
#  (10248, 42, Decimal('9.8000'), 10, Decimal('98.0000')),
#  (10248, 72, Decimal('34.8000'), 5, Decimal('174.0000')),
#  (10249, 14, Decimal('18.6000'), 9, Decimal('167.4000')),
#  (10249, 51, Decimal('42.4000'), 40, Decimal('1696.0000')),
#  (10250, 41, Decimal('7.7000'), 10, Decimal('77.0000')),
#  (10250, 51, Decimal('42.4000'), 35, Decimal('1484.0000')),
#  (10250, 65, Decimal('16.8000'), 15, Decimal('252.0000')),
#  (10251, 22, Decimal('16.8000'), 6, Decimal('100.8000')),
#  (10251, 57, Decimal('15.6000'), 15, Decimal('234.0000')),
#  (10251, 65, Decimal('16.8000'), 20, Decimal('336.0000')),
#  (10252, 20, Decimal('64.8000'), 40, Decimal('2592.0000')),
#  (10252, 33, Decimal('2.0000'), 25, Decimal('50.0000')),
#  (10252, 60, Decimal('27.2000'), 40, Decimal('1088.0000')),
# ...

# %% [markdown]
# ## M14. Sample counting

# %%
# %%sql
# SELECT TotalCustomers = COUNT(*)
# FROM Customers
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(91,)]

# %% [markdown]
# ## M15. Find the first event

# %%
# %%sql
# SELECT FirstOrder = MIN(OrderDate)
# FROM Orders
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(datetime.datetime(1996, 7, 4, 0, 0),)]

# %% [markdown]
# ## M16. Subsetting
# Show the list of countries where there are customers

# %%
# %%sql
# SELECT Country
# FROM Customers
# GROUP BY Country
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Argentina',),
#  ('Austria',),
#  ('Belgium',),
#  ('Brazil',),
#  ('Canada',),
#  ('Denmark',),
#  ('Finland',),
#  ('France',),
#  ('Germany',),
#  ('Ireland',),
#  ('Italy',),
#  ('Mexico',),
#  ('Norway',),
#  ('Poland',),
#  ('Portugal',),
#  ('Spain',),
#  ('Sweden',),
#  ('Switzerland',),
#  ('UK',),
#  ('USA',),
#  ('Venezuela',)]

# %% [markdown]
# ## M17. Counting by group

# %%
# %%sql
# SELECT ContactTitle, TotalContactTitle = COUNT(*)
# FROM Customers
# GROUP BY ContactTitle
# ORDER BY COUNT(*) DESC
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Owner', 17),
#  ('Sales Representative', 17),
#  ('Marketing Manager', 12),
#  ('Sales Manager', 11),
#  ('Accounting Manager', 10),
#  ('Sales Associate', 7),
#  ('Marketing Assistant', 6),
#  ('Sales Agent', 5),
#  ('Assistant Sales Agent', 2),
#  ('Order Administrator', 2),
#  ('Assistant Sales Representative', 1),
#  ('Owner/Marketing Assistant', 1)]

# %% [markdown]
# ## M18. Data merging with aliased tables

# %%
# %%sql
# SELECT ProductID, ProductName, Supplier = CompanyName
# FROM Products P -- Aliased table
# JOIN Suppliers S -- Aliased table
# ON P.SupplierID = S.SupplierID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(1, 'Chai', 'Exotic Liquids'),
#  (2, 'Chang', 'Exotic Liquids'),
#  (3, 'Aniseed Syrup', 'Exotic Liquids'),
#  (4, "Chef Anton's Cajun Seasoning", 'New Orleans Cajun Delights'),
#  (5, "Chef Anton's Gumbo Mix", 'New Orleans Cajun Delights'),
#  (6, "Grandma's Boysenberry Spread", "Grandma Kelly's Homestead"),
#  (7, "Uncle Bob's Organic Dried Pears", "Grandma Kelly's Homestead"),
#  (8, 'Northwoods Cranberry Sauce', "Grandma Kelly's Homestead"),
#  (9, 'Mishi Kobe Niku', 'Tokyo Traders'),
#  (10, 'Ikura', 'Tokyo Traders'),
#  (11, 'Queso Cabrales', "Cooperativa de Quesos 'Las Cabras'"),
#  (12, 'Queso Manchego La Pastora', "Cooperativa de Quesos 'Las Cabras'"),
#  (13, 'Konbu', "Mayumi's"),
#  (14, 'Tofu', "Mayumi's"),
#  (15, 'Genen Shouyu', "Mayumi's"),
#  (16, 'Pavlova', 'Pavlova, Ltd.'),
#  (17, 'Alice Mutton', 'Pavlova, Ltd.'),
#  (18, 'Carnarvon Tigers', 'Pavlova, Ltd.'),
# ...

# %% [markdown]
# ## M19. Data chopping, Table targeting

# %%
# %%sql
# SELECT OrderID, OrderDate = CONVERT(DATE, OrderDate), Shipper = CompanyName
# FROM Orders
# JOIN Shippers
# ON Shippers.ShipperID = Orders.ShipVia
# WHERE OrderID < 10300
# ORDER BY OrderID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(10248, datetime.date(1996, 7, 4), 'Federal Shipping'),
#  (10249, datetime.date(1996, 7, 5), 'Speedy Express'),
#  (10250, datetime.date(1996, 7, 8), 'United Package'),
#  (10251, datetime.date(1996, 7, 8), 'Speedy Express'),
#  (10252, datetime.date(1996, 7, 9), 'United Package'),
#  (10253, datetime.date(1996, 7, 10), 'United Package'),
#  (10254, datetime.date(1996, 7, 11), 'United Package'),
#  (10255, datetime.date(1996, 7, 12), 'Federal Shipping'),
#  (10256, datetime.date(1996, 7, 15), 'United Package'),
#  (10257, datetime.date(1996, 7, 16), 'Federal Shipping'),
#  (10258, datetime.date(1996, 7, 17), 'Speedy Express'),
#  (10259, datetime.date(1996, 7, 18), 'Federal Shipping'),
#  (10260, datetime.date(1996, 7, 19), 'Speedy Express'),
#  (10261, datetime.date(1996, 7, 19), 'United Package'),
#  (10262, datetime.date(1996, 7, 22), 'Federal Shipping'),
# ...

# %%
# %%sql
# SELECT OrderID, OrderDate = CONVERT(DATE, OrderDate), Shipper = S.CompanyName
# FROM Orders O
# JOIN Shippers S
# ON S.ShipperID = O.ShipVia
# WHERE O.OrderID < 10300
# ORDER BY O.OrderID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(10248, datetime.date(1996, 7, 4), 'Federal Shipping'),
#  (10249, datetime.date(1996, 7, 5), 'Speedy Express'),
#  (10250, datetime.date(1996, 7, 8), 'United Package'),
#  (10251, datetime.date(1996, 7, 8), 'Speedy Express'),
#  (10252, datetime.date(1996, 7, 9), 'United Package'),
#  (10253, datetime.date(1996, 7, 10), 'United Package'),
#  (10254, datetime.date(1996, 7, 11), 'United Package'),
#  (10255, datetime.date(1996, 7, 12), 'Federal Shipping'),
#  (10256, datetime.date(1996, 7, 15), 'United Package'),
#  (10257, datetime.date(1996, 7, 16), 'Federal Shipping'),
#  (10258, datetime.date(1996, 7, 17), 'Speedy Express'),
#  (10259, datetime.date(1996, 7, 18), 'Federal Shipping'),
#  (10260, datetime.date(1996, 7, 19), 'Speedy Express'),
#  (10261, datetime.date(1996, 7, 19), 'United Package'),
#  (10262, datetime.date(1996, 7, 22), 'Federal Shipping'),
# ...

# %% [markdown]
# A case where table aliasing is a necessity.Otherwise, the system fails to identify from which table Column SupplierID comes.

# %%
# %%sql
# SELECT ProductID, ProductName, Supplier = CompanyName, Suppliers.SupplierID
# FROM Products
# JOIN Suppliers
# ON Products.SupplierID = Suppliers.SupplierID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(1, 'Chai', 'Exotic Liquids', 1),
#  (2, 'Chang', 'Exotic Liquids', 1),
#  (3, 'Aniseed Syrup', 'Exotic Liquids', 1),
#  (4, "Chef Anton's Cajun Seasoning", 'New Orleans Cajun Delights', 2),
#  (5, "Chef Anton's Gumbo Mix", 'New Orleans Cajun Delights', 2),
#  (6, "Grandma's Boysenberry Spread", "Grandma Kelly's Homestead", 3),
#  (7, "Uncle Bob's Organic Dried Pears", "Grandma Kelly's Homestead", 3),
#  (8, 'Northwoods Cranberry Sauce', "Grandma Kelly's Homestead", 3),
#  (9, 'Mishi Kobe Niku', 'Tokyo Traders', 4),
#  (10, 'Ikura', 'Tokyo Traders', 4),
#  (11, 'Queso Cabrales', "Cooperativa de Quesos 'Las Cabras'", 5),
#  (12, 'Queso Manchego La Pastora', "Cooperativa de Quesos 'Las Cabras'", 5),
#  (13, 'Konbu', "Mayumi's", 6),
#  (14, 'Tofu', "Mayumi's", 6),
#  (15, 'Genen Shouyu', "Mayumi's", 6),
#  (16, 'Pavlova', 'Pavlova, Ltd.', 7),
# ...

# %% [markdown]
# ## M20. Aggregate functions

# %%
# %%sql
# SELECT CategoryName, TotalProducts = COUNT(*)
# FROM Products
# JOIN Categories
# ON Products.CategoryID = Categories.CategoryID
# GROUP BY CategoryName
# ORDER BY COUNT(*) DESC
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Confections', 13),
#  ('lol', 12),
#  ('Condiments', 12),
#  ('Seafood', 12),
#  ('Dairy Products', 10),
#  ('Grains/Cereals', 7),
#  ('Meat/Poultry', 6),
#  ('Produce', 5)]

# %% [markdown]
# ## M21. Groupping

# %%
# %%sql
# SELECT Country, City, TotalCustomer = COUNT(*)
# FROM Customers
# GROUP BY Country, City
# ORDER BY COUNT(*) DESC
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('UK', 'London', 6),
#  ('Mexico', 'México D.F.', 5),
#  ('Brazil', 'Sao Paulo', 4),
#  ('Brazil', 'Rio de Janeiro', 3),
#  ('Spain', 'Madrid', 3),
#  ('Argentina', 'Buenos Aires', 3),
#  ('France', 'Paris', 2),
#  ('USA', 'Portland', 2),
#  ('France', 'Nantes', 2),
#  ('Portugal', 'Lisboa', 2),
#  ('Finland', 'Oulu', 1),
#  ('Italy', 'Reggio Emilia', 1),
#  ('France', 'Reims', 1),
#  ('Brazil', 'Resende', 1),
#  ('Austria', 'Salzburg', 1),
#  ('Venezuela', 'San Cristóbal', 1),
#  ('USA', 'San Francisco', 1),
#  ('USA', 'Seattle', 1),
#  ('Spain', 'Sevilla', 1),
#  ('Norway', 'Stavern', 1),
#  ('France', 'Strasbourg', 1),
#  ('Germany', 'Stuttgart', 1),
#  ('Italy', 'Torino', 1),
#  ('France', 'Toulouse', 1),
#  ('Canada', 'Tsawassen', 1),
#  ('Canada', 'Vancouver', 1),
#  ('France', 'Versailles', 1),
#  ('USA', 'Walla Walla', 1),
#  ('Poland', 'Warszawa', 1),
# ...

# %% [markdown]
# ## M22. Subsetting

# %%
# %%sql
# SELECT ProductID, ProductName, UnitsInStock, ReorderLevel
# FROM Products
# WHERE UnitsInStock <= ReorderLevel
# ORDER BY ProductID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(2, 'Chang', 17, 25),
#  (3, 'Aniseed Syrup', 13, 25),
#  (5, "Chef Anton's Gumbo Mix", 0, 0),
#  (11, 'Queso Cabrales', 22, 30),
#  (17, 'Alice Mutton', 0, 0),
#  (21, "Sir Rodney's Scones", 3, 5),
#  (29, 'Thüringer Rostbratwurst', 0, 0),
#  (30, 'Nord-Ost Matjeshering', 10, 15),
#  (31, 'Gorgonzola Telino', 0, 20),
#  (32, 'Mascarpone Fabioli', 9, 25),
#  (37, 'Gravad lax', 11, 25),
#  (43, 'Ipoh Coffee', 17, 25),
#  (45, 'Rogede sild', 5, 15),
#  (48, 'Chocolade', 15, 25),
#  (49, 'Maxilaku', 10, 15),
#  (53, 'Perth Pasties', 0, 0),
#  (56, 'Gnocchi di nonna Alice', 21, 30),
#  (64, 'Wimmers gute Semmelknödel', 22, 30),
#  (66, 'Louisiana Hot Spiced Okra', 4, 20),
#  (68, 'Scottish Longbreads', 6, 15),
#  (70, 'Outback Lager', 15, 30),
#  (74, 'Longlife Tofu', 4, 5)]

# %% [markdown]
# ## M23. Subsetting (continued)

# %%
# %%sql
# SELECT * FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'Products'
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('NorthWind', 'dbo', 'Products', 'ProductID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Products', 'ProductName', 2, None, 'NO', 'nvarchar', 40, 80, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
#  ('NorthWind', 'dbo', 'Products', 'SupplierID', 3, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Products', 'CategoryID', 4, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NorthWind', 'dbo', 'Products', 'QuantityPerUnit', 5, None, 'YES', 'nvarchar', 20, 40, None, None, None, None, None, None, 'UNICODE', None, None, 'SQL_Latin1_General_CP1_CI_AS', None, None, None),
# ...

# %%
# %%sql
# SELECT ProductID, ProductName, UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
# FROM Products
# WHERE UnitsInStock + UnitsOnOrder <= ReorderLevel AND Discontinued = 0
# ORDER BY ProductID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(30, 'Nord-Ost Matjeshering', 10, 0, 15, False),
#  (70, 'Outback Lager', 15, 10, 30, False)]

# %% [markdown]
# ## M24. Hierachical sorting

# %%
# %%sql
# SELECT CustomerID, CompanyName, Region
# FROM Customers
# ORDER BY CASE WHEN Region IS NULL THEN 1 ELSE 0 END, Region, CustomerID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('OLDWO', 'Old World Delicatessen', 'AK'),
#  ('BOTTM', 'Bottom-Dollar Markets', 'BC'),
#  ('LAUGB', 'Laughing Bacchus Wine Cellars', 'BC'),
#  ('LETSS', "Let's Stop N Shop", 'CA'),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 'Co. Cork'),
#  ('GROSR', 'GROSELLA-Restaurante', 'DF'),
#  ('SAVEA', 'Save-a-lot Markets', 'ID'),
#  ('ISLAT', 'Island Trading', 'Isle of Wight'),
#  ('LILAS', 'LILA-Supermercado', 'Lara'),
#  ('THECR', 'The Cracker Box', 'MT'),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 'NM'),
#  ('LINOD', 'LINO-Delicateses', 'Nueva Esparta'),
#  ('GREAL', 'Great Lakes Food Market', 'OR'),
#  ('HUNGC', 'Hungry Coyote Import Store', 'OR'),
#  ('LONEP', 'Lonesome Pine Restaurant', 'OR'),
#  ('THEBI', 'The Big Cheese', 'OR'),
#  ('MEREP', 'Mère Paillarde', 'Québec'),
#  ('HANAR', 'Hanari Carnes', 'RJ'),
#  ('QUEDE', 'Que Delícia', 'RJ'),
# ...

# %% [markdown]
# ## M25. Show samples with extreme values

# %%
# %%sql
# SELECT TOP 3 ShipCountry, AverageFreight = AVG(Freight)
# FROM Orders
# GROUP BY ShipCountry
# ORDER BY AverageFreight DESC
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Austria', Decimal('184.7875')),
#  ('Ireland', Decimal('145.0126')),
#  ('USA', Decimal('112.8794'))]

# %% [markdown]
# ## M26. Zoom in samples in a fixed time frame

# %%
# %%sql
# SELECT ShipCountry, OrderDate FROM Orders
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('France', datetime.datetime(1996, 7, 4, 0, 0)),
#  ('Germany', datetime.datetime(1996, 7, 5, 0, 0)),
#  ('Brazil', datetime.datetime(1996, 7, 8, 0, 0)),
#  ('France', datetime.datetime(1996, 7, 8, 0, 0)),
#  ('Belgium', datetime.datetime(1996, 7, 9, 0, 0)),
#  ('Brazil', datetime.datetime(1996, 7, 10, 0, 0)),
#  ('Switzerland', datetime.datetime(1996, 7, 11, 0, 0)),
#  ('Switzerland', datetime.datetime(1996, 7, 12, 0, 0)),
#  ('Brazil', datetime.datetime(1996, 7, 15, 0, 0)),
#  ('Venezuela', datetime.datetime(1996, 7, 16, 0, 0)),
#  ('Austria', datetime.datetime(1996, 7, 17, 0, 0)),
#  ('Mexico', datetime.datetime(1996, 7, 18, 0, 0)),
#  ('Germany', datetime.datetime(1996, 7, 19, 0, 0)),
#  ('Brazil', datetime.datetime(1996, 7, 19, 0, 0)),
#  ('USA', datetime.datetime(1996, 7, 22, 0, 0)),
#  ('Austria', datetime.datetime(1996, 7, 23, 0, 0)),
# ...

# %%
# Method 1
# %%sql
SELECT TOP 3 ShipCountry, AverageFreight = AVG(Freight)
FROM Orders
WHERE OrderDate >= '1996-01-01' AND OrderDate < '1997-01-01'
GROUP BY ShipCountry
ORDER BY AverageFreight DESC;
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Austria', Decimal('156.8862')),
#  ('Brazil', Decimal('94.1453')),
#  ('Norway', Decimal('93.6300'))]

# %%
# Method 2
# %%sql
SELECT TOP 3 ShipCountry, AverageFreight = AVG(Freight)
FROM Orders
WHERE YEAR(OrderDate) = 1996
GROUP BY ShipCountry
ORDER BY AverageFreight DESC;
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Austria', Decimal('156.8862')),
#  ('Brazil', Decimal('94.1453')),
#  ('Norway', Decimal('93.6300'))]

# %% [markdown]
# ## M27 and M28. Outliers skew the high freight charge rankings

# %%
# %sql mssql+pyodbc://sa:1234@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC+Driver+13+for+SQL+Server
# Out:
# 'Connected: sa@NorthWind2016'

# %% [markdown]
# Method 1.

# %%
# %%sql
# SELECT TOP 4 ShipCountry, AverageFreight = AVG(Freight)
# FROM Orders
# WHERE OrderDate BETWEEN '20150101' AND '20151231' -- this 20151231 is only equivalent to 20151-12-31 00:00:00, not the full day
# GROUP BY ShipCountry
# ORDER BY AverageFreight DESC;
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Austria', Decimal('178.3642')),
#  ('Switzerland', Decimal('117.1775')),
#  ('Sweden', Decimal('105.1600')),
#  ('Canada', Decimal('99.2800'))]

# %% [markdown]
# Method 2.

# %%
# %%sql
# SELECT TOP 4 ShipCountry, AverageFreight = AVG(Freight)
# FROM Orders
# WHERE YEAR(OrderDate) = 2015
# GROUP BY ShipCountry
# ORDER BY AverageFreight DESC;
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Austria', Decimal('178.3642')),
#  ('Switzerland', Decimal('117.1775')),
#  ('France', Decimal('113.9910')),
#  ('Sweden', Decimal('105.1600'))]

# %%
Method 3.

# %%
# %%sql
# SELECT TOP 4 ShipCountry, AverageFreight = AVG(Freight)
# FROM Orders
# WHERE OrderDate >= '20150101' AND OrderDate < '20160101'
# GROUP BY ShipCountry
# ORDER BY AverageFreight DESC;
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Austria', Decimal('178.3642')),
#  ('Switzerland', Decimal('117.1775')),
#  ('France', Decimal('113.9910')),
#  ('Sweden', Decimal('105.1600'))]

# %% [markdown]
# The result of Method 1 is different from those of Methods 2 and 3.

# %% [markdown]
# ## M29. Merge of multiple tables

# %%
# %%sql
# SELECT Employees.EmployeeID, Employees.LastName, Orders.OrderID, Products.ProductName, OrderDetails.Quantity
# FROM Employees
#     JOIN Orders ON Orders.EmployeeID = Employees.EmployeeID
#     JOIN OrderDetails ON Orders.OrderID = OrderDetails.OrderID
#     JOIN Products ON Products.ProductID = OrderDetails.ProductID
# ORDER BY Orders.OrderID, Products.ProductID;
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(5, 'Buchanan', 10248, 'Queso Cabrales', 12),
#  (5, 'Buchanan', 10248, 'Singaporean Hokkien Fried Mee', 10),
#  (5, 'Buchanan', 10248, 'Mozzarella di Giovanni', 5),
#  (6, 'Suyama', 10249, 'Tofu', 9),
#  (6, 'Suyama', 10249, 'Manjimup Dried Apples', 40),
#  (4, 'Peacock', 10250, "Jack's New England Clam Chowder", 10),
#  (4, 'Peacock', 10250, 'Manjimup Dried Apples', 35),
#  (4, 'Peacock', 10250, 'Louisiana Fiery Hot Pepper Sauce', 15),
#  (3, 'Leverling', 10251, "Gustaf's Knäckebröd", 6),
#  (3, 'Leverling', 10251, 'Ravioli Angelo', 15),
#  (3, 'Leverling', 10251, 'Louisiana Fiery Hot Pepper Sauce', 20),
#  (4, 'Peacock', 10252, "Sir Rodney's Marmalade", 40),
#  (4, 'Peacock', 10252, 'Geitost', 25),
#  (4, 'Peacock', 10252, 'Camembert Pierrot', 40),
# ...

# %% [markdown]
# ## M30. Customers who never work with any employees of the trade company \[read data\]

# %%
# %load_ext sql
# %sql mssql+pyodbc://sa:1234@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC+Driver+13+for+SQL+Server
# Out:
# 'Connected: sa@NorthWind2016'

# %%
# %%sql
# SELECT Customers_CustomerID = Customers.CustomerID, Orders_CustomerID = Orders.CustomerID, Orders.EmployeeID
# FROM Customers
#     LEFT JOIN Orders
#     ON Orders.CustomerID = Customers.CustomerID
# WHERE Orders.CustomerID IS NULL;
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('PARIS', None, None), ('FISSA', None, None)]

# %% [markdown]
# ## M31. Customers who never work with employee \#4

# %%
# %%sql
# SELECT Customers.CustomerID, Orders.CustomerID
# FROM Customers
#     LEFT JOIN Orders
#     ON Orders.CustomerID = Customers.CustomerID AND Orders.EmployeeID = 4
# WHERE Orders.CustomerID IS NULL
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('SEVES', None, None),
#  ('THEBI', None, None),
#  ('LAZYK', None, None),
#  ('GROSR', None, None),
#  ('PARIS', None, None),
#  ('FISSA', None, None),
#  ('SPECD', None, None),
#  ('LAUGB', None, None),
#  ('PRINI', None, None),
#  ('VINET', None, None),
#  ('FRANR', None, None),
#  ('CONSH', None, None),
#  ('NORTS', None, None),
#  ('PERIC', None, None),
#  ('DUMON', None, None),
#  ('SANTG', None, None)]

# %% [markdown]
# ## M32. Conditional selection
# Customers who ever made a `single` order worht of more than \$10000 in 2016.

# %%
# %%sql
# SELECT Customers.CustomerID, Customers.CompanyName, Orders.OrderID, TotalOrderAmount = SUM(Quantity * UnitPrice)
# FROM Customers
#     JOIN Orders ON Orders.CustomerID = Customers.CustomerID
#     JOIN OrderDetails ON Orders.OrderID = OrderDetails.OrderID
# WHERE OrderDate BETWEEN '2016-01-01' AND '2017-01-01'
# GROUP BY Customers.CustomerID, Customers.CompanyName, Orders.Orderid
# HAVING SUM(Quantity * UnitPrice) > 10000
# ORDER BY TotalOrderAmount DESC
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('QUICK', 'QUICK-Stop', 10865, Decimal('17250.0000')),
#  ('SAVEA', 'Save-a-lot Markets', 11030, Decimal('16321.9000')),
#  ('HANAR', 'Hanari Carnes', 10981, Decimal('15810.0000')),
#  ('KOENE', 'Königlich Essen', 10817, Decimal('11490.7000')),
#  ('RATTC', 'Rattlesnake Canyon Grocery', 10889, Decimal('11380.0000')),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', 10897, Decimal('10835.2400'))]

# %% [markdown]
# ## M33. Conditional Selection (continued)
# Show customers whose total purchase exceeds $15000 in 2016.

# %%
# %%sql
# SELECT Customers.CustomerID, Customers.CompanyName, TotalOrderAmount = SUM(Quantity * UnitPrice)
# FROM Customers
#     JOIN Orders ON Orders.CustomerID = Customers.CustomerID
#     JOIN OrderDetails ON Orders.OrderID = OrderDetails.OrderID
# WHERE OrderDate BETWEEN '2016-01-01' AND '2017-01-01'
# GROUP BY Customers.CustomerID, Customers.CompanyName ---remove this feature Orders.Orderid
# HAVING SUM(Quantity * UnitPrice) > 10000
# ORDER BY TotalOrderAmount DESC
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('SAVEA', 'Save-a-lot Markets', Decimal('42806.2500')),
#  ('ERNSH', 'Ernst Handel', Decimal('42598.9000')),
#  ('QUICK', 'QUICK-Stop', Decimal('40526.9900')),
#  ('HANAR', 'Hanari Carnes', Decimal('24238.0500')),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', Decimal('22796.3400')),
#  ('RATTC', 'Rattlesnake Canyon Grocery', Decimal('21725.6000')),
#  ('KOENE', 'Königlich Essen', Decimal('20204.9500')),
#  ('FOLKO', 'Folk och fä HB', Decimal('15973.8500')),
#  ('WHITC', 'White Clover Markets', Decimal('15278.9000')),
#  ('BOTTM', 'Bottom-Dollar Markets', Decimal('12227.4000')),
#  ('SUPRD', 'Suprêmes délices', Decimal('11862.5000')),
#  ('GREAL', 'Great Lakes Food Market', Decimal('10562.5800')),
#  ('LINOD', 'LINO-Delicateses', Decimal('10085.6000'))]

# %% [markdown]
# ## M34. Conditional selection (continued)
# Take the discount into consideration when calculating high-value customers

# %%
# %%sql
# SELECT Customers.CustomerID, Customers.CompanyName, TotalsWithoutDiscount = SUM(Quantity * UnitPrice),  TotalsWithDiscount = SUM(Quantity * UnitPrice * (1 - Discount))
# FROM Customers
#     JOIN Orders ON Orders.CustomerID = Customers.CustomerID
#     JOIN OrderDetails ON Orders.OrderID = OrderDetails.OrderID
# WHERE OrderDate BETWEEN '2016-01-01' AND '2017-01-01'
# GROUP BY Customers.CustomerID, Customers.CompanyName ---remove this feature Orders.Orderid
# HAVING SUM(Quantity * UnitPrice) > 10000
# ORDER BY TotalsWithDiscount DESC
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [('ERNSH', 'Ernst Handel', Decimal('42598.9000'), 41210.65002441406),
#  ('QUICK', 'QUICK-Stop', Decimal('40526.9900'), 37217.315002441406),
#  ('SAVEA', 'Save-a-lot Markets', Decimal('42806.2500'), 36310.10977935791),
#  ('HANAR', 'Hanari Carnes', Decimal('24238.0500'), 23821.199989318848),
#  ('RATTC', 'Rattlesnake Canyon Grocery', Decimal('21725.6000'), 21238.270441055298),
#  ('HUNGO', 'Hungry Owl All-Night Grocers', Decimal('22796.3400'), 20402.11993408203),
#  ('KOENE', 'Königlich Essen', Decimal('20204.9500'), 19582.773986816406),
#  ('WHITC', 'White Clover Markets', Decimal('15278.9000'), 15278.89998626709),
#  ('FOLKO', 'Folk och fä HB', Decimal('15973.8500'), 13644.067497253418),
#  ('SUPRD', 'Suprêmes délices', Decimal('11862.5000'), 11644.599998474121),
# ...

# %% [markdown]
# ## M35. Datetime function
# Show the sales at the end of the month.

# %%
# %%sql
# SELECT EmployeeID, OrderID, OrderDate
# FROM Orders
# WHERE OrderDate = EOMONTH(OrderDate)
# ORDER BY EmployeeID, OrderID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(1, 10461, datetime.datetime(2015, 2, 28, 0, 0)),
#  (1, 10616, datetime.datetime(2015, 7, 31, 0, 0)),
#  (2, 10583, datetime.datetime(2015, 6, 30, 0, 0)),
#  (2, 10686, datetime.datetime(2015, 9, 30, 0, 0)),
#  (2, 10989, datetime.datetime(2016, 3, 31, 0, 0)),
#  (2, 11060, datetime.datetime(2016, 4, 30, 0, 0)),
#  (3, 10432, datetime.datetime(2015, 1, 31, 0, 0)),
#  (3, 10988, datetime.datetime(2016, 3, 31, 0, 0)),
#  (3, 11063, datetime.datetime(2016, 4, 30, 0, 0)),
#  (4, 10343, datetime.datetime(2014, 10, 31, 0, 0)),
#  (4, 10522, datetime.datetime(2015, 4, 30, 0, 0)),
#  (4, 10584, datetime.datetime(2015, 6, 30, 0, 0)),
#  (4, 10617, datetime.datetime(2015, 7, 31, 0, 0)),
#  (4, 10725, datetime.datetime(2015, 10, 31, 0, 0)),
#  (4, 11061, datetime.datetime(2016, 4, 30, 0, 0)),
# ...

# %% [markdown]
# ## M36. Most frequent
# Show the 10 orders with the most line items, in order of total line items.

# %%
# %%sql
# SELECT TOP 10 Orders.OrderID, TotalOrderDetails = COUNT(*)
# FROM Orders
#     JOIN OrderDetails ON Orders.OrderID = OrderDetails.OrderID
# GROUP BY Orders.OrderID
# ORDER BY COUNT(*) DESC
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(11077, 25),
#  (10979, 6),
#  (10657, 6),
#  (10847, 6),
#  (10845, 5),
#  (10836, 5),
#  (10714, 5),
#  (10670, 5),
#  (10691, 5),
#  (10698, 5)]

# %% [markdown]
# ## M37. Data raffling
# Show a random set of 2\% of all orders.
# Reference: [NewID](https://www.techrepublic.com/article/generate-random-sets-in-sql-server-with-newid/)()

# %%
# %%sql
# SELECT TOP 2 PERCENT OrderID
# FROM Orders
# ORDER BY NewID()
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(10849,),
#  (10260,),
#  (10879,),
#  (10865,),
#  (10354,),
#  (10745,),
#  (10642,),
#  (10749,),
#  (10431,),
#  (10797,),
#  (10734,),
#  (10772,),
#  (10463,),
#  (10775,),
#  (10643,),
#  (10567,),
#  (10604,)]

# %% [markdown]
# ## M38. Identifying duplicates
# The HAVING clause was added to SQL because the WHERE keyword could not be used with aggregate functions.

# %%
# %%sql
# SELECT OrderID
# FROM OrderDetails
# WHERE Quantity >=60 -- the salesperson said the vaolume of the duplicats exceed 60.
# GROUP BY OrderID, Quantity
# HAVING Count(*) > 1
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(10263,), (10263,), (10990,), (10658,), (11030,)]

# %% [markdown]
# ## M39. Derived tables
# Show the details of the duplicated items (continued).
#
# The first part deals with the duplicated items. <br>
# The second part shows the details of the identified duplicates. <br>

# %%
# %%sql
# ; WITH PotentialDuplicates AS(
#     SELECT OrderID
#     FROM OrderDetails
#     WHERE Quantity >= 60
#     GROUP BY OrderID, Quantity
#     HAVING COUNT(*) > 1
# )
#
# SELECT OrderID, ProductID, UnitPrice, Quantity, Discount
# FROM OrderDetails
# WHERE OrderID IN (SELECT OrderID FROM PotentialDuplicates)
# ORDER BY OrderID, Quantity
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [(10263, 16, Decimal('13.9000'), 60, 0.25),
#  (10263, 30, Decimal('20.7000'), 60, 0.25),
#  (10263, 24, Decimal('3.6000'), 65, 0.0),
#  (10263, 74, Decimal('8.0000'), 65, 0.25),
#  (10658, 60, Decimal('34.0000'), 55, 0.05000000074505806),
#  (10658, 21, Decimal('10.0000'), 60, 0.0),
#  (10658, 40, Decimal('18.4000'), 70, 0.05000000074505806),
#  (10658, 77, Decimal('13.0000'), 70, 0.05000000074505806),
#  (10990, 34, Decimal('14.0000'), 60, 0.15000000596046448),
#  (10990, 21, Decimal('10.0000'), 65, 0.0),
#  (10990, 55, Decimal('24.0000'), 65, 0.15000000596046448),
#  (10990, 61, Decimal('28.5000'), 66, 0.15000000596046448),
#  (11030, 29, Decimal('123.7900'), 60, 0.25),
#  (11030, 5, Decimal('21.3500'), 70, 0.0),
#  (11030, 2, Decimal('19.0000'), 100, 0.25),
# ...

# %% [markdown]
# ## M40. Equivalent to M39.

# %%
# %%sql
# SELECT OrderDetails.OrderID, ProductID, UnitPrice, Quantity, Discount
# FROM OrderDetails
#     JOIN (
#         SELECT DISTINCT OrderID --<<<<
#         FROM OrderDetails
#         WHERE Quantity >= 60
#         GROUP BY OrderID, Quantity
#         HAVING COUNT(*) > 1
#     ) PotentialProblemOrders
#     On PotentialProblemOrders.OrderID = OrderDetails.OrderID
# ORDER BY OrderID, ProductID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(10263, 16, Decimal('13.9000'), 60, 0.25),
#  (10263, 24, Decimal('3.6000'), 65, 0.0),
#  (10263, 30, Decimal('20.7000'), 60, 0.25),
#  (10263, 74, Decimal('8.0000'), 65, 0.25),
#  (10658, 21, Decimal('10.0000'), 60, 0.0),
#  (10658, 40, Decimal('18.4000'), 70, 0.05000000074505806),
#  (10658, 60, Decimal('34.0000'), 55, 0.05000000074505806),
#  (10658, 77, Decimal('13.0000'), 70, 0.05000000074505806),
#  (10990, 21, Decimal('10.0000'), 65, 0.0),
#  (10990, 34, Decimal('14.0000'), 60, 0.15000000596046448),
#  (10990, 55, Decimal('24.0000'), 65, 0.15000000596046448),
#  (10990, 61, Decimal('28.5000'), 66, 0.15000000596046448),
#  (11030, 2, Decimal('19.0000'), 100, 0.25),
#  (11030, 5, Decimal('21.3500'), 70, 0.0),
#  (11030, 29, Decimal('123.7900'), 60, 0.25),
# ...

# %% [markdown]
# ## M41. Datetime function

# %%
# %%sql
# SELECT OrderID, OrderDate = CONVERT(DATE, OrderDate), RequiredDate = CONVERT(DATE, RequiredDate), ShippedDate = CONVERT(DATE, ShippedDate)
# FROM Orders
# WHERE RequiredDate <= ShippedDate
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(10264, datetime.date(2014, 7, 24), datetime.date(2014, 8, 21), datetime.date(2014, 8, 23)),
#  (10271, datetime.date(2014, 8, 1), datetime.date(2014, 8, 29), datetime.date(2014, 8, 30)),
#  (10280, datetime.date(2014, 8, 14), datetime.date(2014, 9, 11), datetime.date(2014, 9, 12)),
#  (10302, datetime.date(2014, 9, 10), datetime.date(2014, 10, 8), datetime.date(2014, 10, 9)),
#  (10309, datetime.date(2014, 9, 19), datetime.date(2014, 10, 17), datetime.date(2014, 10, 23)),
#  (10380, datetime.date(2014, 12, 12), datetime.date(2015, 1, 9), datetime.date(2015, 1, 16)),
#  (10423, datetime.date(2015, 1, 23), datetime.date(2015, 2, 6), datetime.date(2015, 2, 24)),
#  (10427, datetime.date(2015, 1, 27), datetime.date(2015, 2, 24), datetime.date(2015, 3, 3)),
# ...

# %% [markdown]
# ## M42. Datetime function (continued)
# Which salespeople have the most orders being delivered late?

# %%
# %%sql
# SELECT Employees.EmployeeID, LastName, TotalLateOrders = COUNT(*)
# FROM Orders
# JOIN Employees ON Employees.EmployeeID = Orders.EmployeeID
# WHERE RequiredDate <= ShippedDate
# GROUP BY Employees.EmployeeID, Employees.LastName
# ORDER BY TotalLateOrders DESC
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
#    mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind?driver=ODBC Driver 13 for SQL Server
# Done.
# [(4, 'Peacock', 10),
#  (3, 'Leverling', 5),
#  (8, 'Callahan', 5),
#  (9, 'Dodsworth', 5),
#  (7, 'King', 4),
#  (2, 'Fuller', 4),
#  (1, 'Davolio', 3),
#  (6, 'Suyama', 3)]

# %% [markdown]
# ## M43. Multiple Derived tables (continued)

# %%
# %%sql
# ; WITH LateOrders AS(
#     SELECT EmployeeID, TotalOrders = COUNT(*)
#     FROM Orders
#     WHERE RequiredDate <= ShippedDate --<<<
#     GROUP BY EmployeeID
# )
# , AllOrders AS(
#     SELECT EmployeeID, TotalOrders = COUNT(*)
#     FROM Orders
#     GROUP BY EmployeeID
# )
#
# SELECT Employees.EmployeeID, LastName, AllOrders = AllOrders.TotalOrders, LateOrders = LateOrders.TotalOrders
# FROM Employees
# JOIN AllOrders ON AllOrders.EmployeeID = Employees.EmployeeID
# JOIN LateOrders ON LateOrders.EmployeeID = Employees.EmployeeID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [(1, 'Davolio', 123, 3),
#  (2, 'Fuller', 96, 4),
#  (3, 'Leverling', 127, 5),
#  (4, 'Peacock', 156, 10),
#  (6, 'Suyama', 67, 3),
#  (7, 'King', 72, 4),
#  (8, 'Callahan', 104, 5),
#  (9, 'Dodsworth', 43, 5)]

# %% [markdown]
# ## M.44 Left Join (continued)
# Some employees are missing from the last result due to wrong merge method.

# %%
# %%sql
# ; WITH LateOrders AS(
#     SELECT EmployeeID, TotalOrders = COUNT(*)
#     FROM Orders
#     WHERE RequiredDate <= ShippedDate --<<<
#     GROUP BY EmployeeID
# )
# , AllOrders AS(
#     SELECT EmployeeID, TotalOrders = COUNT(*)
#     FROM Orders
#     GROUP BY EmployeeID
# )
#
# SELECT Employees.EmployeeID, LastName, AllOrders = AllOrders.TotalOrders, LateOrders = LateOrders.TotalOrders
# FROM Employees
# JOIN AllOrders ON AllOrders.EmployeeID = Employees.EmployeeID
# LEFT JOIN LateOrders ON LateOrders.EmployeeID = Employees.EmployeeID --<<<
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [(1, 'Davolio', 123, 3),
#  (2, 'Fuller', 96, 4),
#  (3, 'Leverling', 127, 5),
#  (4, 'Peacock', 156, 10),
#  (5, 'Buchanan', 42, None),
#  (6, 'Suyama', 67, 3),
#  (7, 'King', 72, 4),
#  (8, 'Callahan', 104, 5),
#  (9, 'Dodsworth', 43, 5)]

# %% [markdown]
# ## M.45 Date transformation (continued)

# %% [markdown]
# Method 1.

# %%
# %%sql
# ; WITH LateOrders AS(
#     SELECT EmployeeID, TotalOrders = COUNT(*)
#     FROM Orders
#     WHERE RequiredDate <= ShippedDate --<<<
#     GROUP BY EmployeeID
# )
# , AllOrders AS(
#     SELECT EmployeeID, TotalOrders = COUNT(*)
#     FROM Orders
#     GROUP BY EmployeeID
# )
#
# SELECT
#     Employees.EmployeeID,
#     LastName,
#     AllOrders = AllOrders.TotalOrders,
#     LateOrders =
#         CASE WHEN LateOrders.TotalOrders IS NULL THEN 0
#         ELSE LateOrders.TotalOrders
#         END
# FROM Employees
# JOIN AllOrders ON AllOrders.EmployeeID = Employees.EmployeeID
# LEFT JOIN LateOrders ON LateOrders.EmployeeID = Employees.EmployeeID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [(1, 'Davolio', 123, 3),
#  (2, 'Fuller', 96, 4),
#  (3, 'Leverling', 127, 5),
#  (4, 'Peacock', 156, 10),
#  (5, 'Buchanan', 42, 0),
#  (6, 'Suyama', 67, 3),
#  (7, 'King', 72, 4),
#  (8, 'Callahan', 104, 5),
#  (9, 'Dodsworth', 43, 5)]

# %% [markdown]
# Method 2. better just using ISNULL()

# %%
# %%sql
# ; WITH LateOrders AS(
#     SELECT EmployeeID, TotalOrders = COUNT(*)
#     FROM Orders
#     WHERE RequiredDate <= ShippedDate
#     GROUP BY EmployeeID
# )
# , AllOrders AS(
#     SELECT EmployeeID, TotalOrders = COUNT(*)
#     FROM Orders
#     GROUP BY EmployeeID
# )
#
# SELECT Employees.EmployeeID, LastName, AllOrders = AllOrders.TotalOrders, LateOrders = ISNULL(LateOrders.TotalOrders, 0) --<<<
# FROM Employees
# JOIN AllOrders ON AllOrders.EmployeeID = Employees.EmployeeID
# LEFT JOIN LateOrders ON LateOrders.EmployeeID = Employees.EmployeeID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [(1, 'Davolio', 123, 3),
#  (2, 'Fuller', 96, 4),
#  (3, 'Leverling', 127, 5),
#  (4, 'Peacock', 156, 10),
#  (5, 'Buchanan', 42, 0),
#  (6, 'Suyama', 67, 3),
#  (7, 'King', 72, 4),
#  (8, 'Callahan', 104, 5),
#  (9, 'Dodsworth', 43, 5)]

# %% [markdown]
# ## M.46 Normalization

# %%
# %%sql
# ; WITH LateOrders AS(
#     SELECT EmployeeID, TotalOrders = COUNT(*)
#     FROM Orders
#     WHERE RequiredDate <= ShippedDate
#     GROUP BY EmployeeID
# )
# , AllOrders AS(
#     SELECT EmployeeID, TotalOrders = COUNT(*)
#     FROM Orders
#     GROUP BY EmployeeID
# )
#
# SELECT Employees.EmployeeID,
#     LastName,
#     AllOrders = AllOrders.TotalOrders,
#     LateOrders = ISNULL(LateOrders.TotalOrders, 0),
#     PercentLateOrders = ISNULL(LateOrders.TotalOrders, 0) * 1.00 / AllOrders.TotalOrders
# FROM Employees
# JOIN AllOrders ON AllOrders.EmployeeID = Employees.EmployeeID
# LEFT JOIN LateOrders ON LateOrders.EmployeeID = Employees.EmployeeID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [(1, 'Davolio', 123, 3, Decimal('0.0243902439024')),
#  (2, 'Fuller', 96, 4, Decimal('0.0416666666666')),
#  (3, 'Leverling', 127, 5, Decimal('0.0393700787401')),
#  (4, 'Peacock', 156, 10, Decimal('0.0641025641025')),
#  (5, 'Buchanan', 42, 0, Decimal('0E-13')),
#  (6, 'Suyama', 67, 3, Decimal('0.0447761194029')),
#  (7, 'King', 72, 4, Decimal('0.0555555555555')),
#  (8, 'Callahan', 104, 5, Decimal('0.0480769230769')),
#  (9, 'Dodsworth', 43, 5, Decimal('0.1162790697674'))]

# %% [markdown]
# ## M.47 Format Statement
# Display the PercentLateOrders in the format of 2 digits to the right of the decimal point.

# %%
# %%sql
# ; WITH LateOrders AS(
#     SELECT EmployeeID, TotalOrders = COUNT(*)
#     FROM Orders
#     WHERE RequiredDate <= ShippedDate
#     GROUP BY EmployeeID
# )
# , AllOrders AS(
#     SELECT EmployeeID, TotalOrders = COUNT(*)
#     FROM Orders
#     GROUP BY EmployeeID
# )
#
# SELECT Employees.EmployeeID,
#     LastName,
#     AllOrders = AllOrders.TotalOrders,
#     LateOrders = ISNULL(LateOrders.TotalOrders, 0),
#     PercentLateOrders = CONVERT(DECIMAL(10, 2), ISNULL(LateOrders.TotalOrders, 0) * 1.00 / AllOrders.TotalOrders)
# FROM Employees
# JOIN AllOrders ON AllOrders.EmployeeID = Employees.EmployeeID
# LEFT JOIN LateOrders ON LateOrders.EmployeeID = Employees.EmployeeID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [(1, 'Davolio', 123, 3, Decimal('0.02')),
#  (2, 'Fuller', 96, 4, Decimal('0.04')),
#  (3, 'Leverling', 127, 5, Decimal('0.04')),
#  (4, 'Peacock', 156, 10, Decimal('0.06')),
#  (5, 'Buchanan', 42, 0, Decimal('0.00')),
#  (6, 'Suyama', 67, 3, Decimal('0.04')),
#  (7, 'King', 72, 4, Decimal('0.06')),
#  (8, 'Callahan', 104, 5, Decimal('0.05')),
#  (9, 'Dodsworth', 43, 5, Decimal('0.12'))]

# %% [markdown]
# ## M.48 Data binning
# Group customers into groups based on how much they ordered in 2016. <br>
# The bins for categorization are 0 to 1000, 1000 to 5000, 5000 to 10,000, and over 10,000. <br>

# %%
# %%sql
# ; WITH Orders2016 AS(
#     SELECT Customers.CustomerID, Customers.CompanyName, TotalOrderAmount = SUM(Quantity * UnitPrice)
#     FROM Customers
#     JOIN Orders ON Orders.CustomerID = Customers.CustomerID
#     JOIN OrderDetails ON Orders.OrderID = OrderDetails.OrderID
#     WHERE YEAR(OrderDate) = 2016
#     GROUP BY Customers.CustomerID, Customers.CompanyName
# )
# SELECT CustomerID, CompanyName, TotalOrderAmount,
#     CustomerGroup =
#         CASE
#         WHEN TotalOrderAmount BETWEEN 0 AND 1000 THEN 'Low'
#         WHEN TotalOrderAmount BETWEEN 1001 AND 5000 THEN 'Medium'
#         WHEN TotalOrderAmount BETWEEN 5001 AND 10000 THEN 'High'
#         WHEN TotalOrderAmount > 10000 THEN 'Very High'
#         END
# FROM Orders2016
# ORDER BY CustomerID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [('ALFKI', 'Alfreds Futterkiste', Decimal('2302.2000'), 'Medium'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', Decimal('514.4000'), 'Low'),
#  ('ANTON', 'Antonio Moreno Taquería', Decimal('660.0000'), 'Low'),
#  ('AROUT', 'Around the Horn', Decimal('5838.5000'), 'High'),
#  ('BERGS', 'Berglunds snabbköp', Decimal('8110.5500'), 'High'),
#  ('BLAUS', 'Blauer See Delikatessen', Decimal('2160.0000'), 'Medium'),
#  ('BLONP', 'Blondesddsl père et fils', Decimal('730.0000'), 'Low'),
#  ('BOLID', 'Bólido Comidas preparadas', Decimal('280.0000'), 'Low'),
#  ('BONAP', "Bon app'", Decimal('7185.9000'), 'High'),
#  ('BOTTM', 'Bottom-Dollar Markets', Decimal('12227.4000'), 'Very High'),
#  ('BSBEV', "B's Beverages", Decimal('2431.0000'), 'Medium'),
#  ('CACTU', 'Cactus Comidas para llevar', Decimal('1576.8000'), 'Medium'),
# ...

# %% [markdown]
# ## M49. Integer binning issue caused by continuous variables
# Fix the last script so that there is no None shown in the CustomerGroup field.

# %%
# %%sql
# ; WITH Orders2016 AS(
#     SELECT Customers.CustomerID, Customers.CompanyName, TotalOrderAmount = SUM(Quantity * UnitPrice)
#     FROM Customers
#     JOIN Orders ON Orders.CustomerID = Customers.CustomerID
#     JOIN OrderDetails ON Orders.OrderID = OrderDetails.OrderID
#     WHERE YEAR(OrderDate) = 2016
#     GROUP BY Customers.CustomerID, Customers.CompanyName
# )
# SELECT CustomerID, CompanyName, TotalOrderAmount,
#     CustomerGroup =
#         CASE
#         WHEN TotalOrderAmount >= 0 AND TotalOrderAmount < 1000  THEN 'Low'
#         WHEN TotalOrderAmount >= 1000 AND TotalOrderAmount < 5000 THEN 'Medium'
#         WHEN TotalOrderAmount >= 5001 AND TotalOrderAmount < 10000 THEN 'High'
#         WHEN TotalOrderAmount >= 10000 THEN 'Very High'
#         END
# FROM Orders2016
# ORDER BY CustomerID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [('ALFKI', 'Alfreds Futterkiste', Decimal('2302.2000'), 'Medium'),
#  ('ANATR', 'Ana Trujillo Emparedados y helados', Decimal('514.4000'), 'Low'),
#  ('ANTON', 'Antonio Moreno Taquería', Decimal('660.0000'), 'Low'),
#  ('AROUT', 'Around the Horn', Decimal('5838.5000'), 'High'),
#  ('BERGS', 'Berglunds snabbköp', Decimal('8110.5500'), 'High'),
#  ('BLAUS', 'Blauer See Delikatessen', Decimal('2160.0000'), 'Medium'),
#  ('BLONP', 'Blondesddsl père et fils', Decimal('730.0000'), 'Low'),
#  ('BOLID', 'Bólido Comidas preparadas', Decimal('280.0000'), 'Low'),
#  ('BONAP', "Bon app'", Decimal('7185.9000'), 'High'),
#  ('BOTTM', 'Bottom-Dollar Markets', Decimal('12227.4000'), 'Very High'),
#  ('BSBEV', "B's Beverages", Decimal('2431.0000'), 'Medium'),
#  ('CACTU', 'Cactus Comidas para llevar', Decimal('1576.8000'), 'Medium'),
# ...

# %% [markdown]
# ## M50. Integrating M48 with M49 (continued) <<<---

# %%
# %%sql
# ; WITH Orders2016 AS(
#     SELECT Customers.CustomerID, Customers.CompanyName, TotalOrderAmount = SUM(Quantity * UnitPrice)
#     FROM Customers
#     JOIN Orders ON Orders.CustomerID = Customers.CustomerID
#     JOIN OrderDetails ON Orders.OrderID = OrderDetails.OrderID
#     WHERE YEAR(OrderDate) = 2016
#     GROUP BY Customers.CustomerID, Customers.CompanyName
# ), CustomerGrouping AS(
#     SELECT CustomerID, CompanyName, TotalOrderAmount,
#     CustomerGroup =
#         CASE
#         WHEN TotalOrderAmount >= 0 AND TotalOrderAmount < 1000  THEN 'Low'
#         WHEN TotalOrderAmount >= 1000 AND TotalOrderAmount < 5000 THEN 'Medium'
#         WHEN TotalOrderAmount >= 5001 AND TotalOrderAmount < 10000 THEN 'High'
#         WHEN TotalOrderAmount >= 10000 THEN 'Very High'
#         END
#     FROM Orders2016
#     --ORDER BY CustomerID <<< The ORDER BY command is invalid in derived tables.
# )
# SELECT CustomerGroup, TotalInGroup = COUNT(*), PercentageInGroup = COUNT(*) * 1.0 / (SELECT COUNT(*) FROM CustomerGrouping)
# FROM CustomerGrouping
# GROUP BY CustomerGroup
# ORDER BY TotalInGroup DESC
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [('Medium', 35, Decimal('0.432098765432')),
#  ('Low', 20, Decimal('0.246913580246')),
#  ('Very High', 13, Decimal('0.160493827160')),
#  ('High', 12, Decimal('0.148148148148')),
#  (None, 1, Decimal('0.012345679012'))]

# %% [markdown]
# ## M51. incomplete

# %%
# %%sql
# ; WITH Orders2016 AS(
#     SELECT Customers.CustomerID, Customers.CompanyName, TotalOrderAmount = SUM(Quantity * UnitPrice)
#     FROM Customers
#     JOIN Orders ON Orders.CustomerID = Customers.CustomerID
#     JOIN OrderDetails ON Orders.OrderID = OrderDetails.OrderID
#     WHERE YEAR(OrderDate) = 2016
#     GROUP BY Customers.CustomerID, Customers.CompanyName
# )
#
# SELECT CustomerID, CompanyName, TotalOrderAmount, CustomerGroupName
# FROM Orders2016
# JOIN CustomerGroupThresholds ON Orders2016.TotalOrderAmount BETWEEN CustomerGroupThresholds.RangeBottom AND CustomerGroupThresholds.RangeTop
# ORDER BY CustomerID
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# ...

# %% [markdown]
# ## M52. Show unique elements after merge

# %%
# %%sql
# SELECT Country FROM Customers
# UNION
# SELECT Country FROM Suppliers
# ORDER BY Country
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# [('Argentina',),
#  ('Australia',),
#  ('Austria',),
#  ('Belgium',),
#  ('Brazil',),
#  ('Canada',),
#  ('Denmark',),
#  ('Finland',),
#  ('France',),
#  ('Germany',),
#  ('Ireland',),
#  ('Italy',),
#  ('Japan',),
#  ('Mexico',),
#  ('Netherlands',),
#  ('Norway',),
#  ('Poland',),
#  ('Portugal',),
#  ('Singapore',),
#  ('Spain',),
#  ('Sweden',),
#  ('Switzerland',),
#  ('UK',),
#  ('USA',),
#  ('Venezuela',)]

# %% [markdown]
# ## M53. Add more details after merge (continued)

# %%
# %%sql
# ; WITH SupplierCountries AS(
#     SELECT DISTINCT Country FROM Suppliers
# ), CustomerCountries AS(
#     SELECT DISTINCT Country FROM Customers
# )
# SELECT SupplierCountry = SupplierCountries.Country, CustomerCountry = CustomerCountries.Country
# FROM SupplierCountries
# FULL OUTER JOIN CustomerCountries ON CustomerCountries.Country = SupplierCountries.Country
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [(None, 'Argentina'),
#  ('Australia', None),
#  (None, 'Austria'),
#  (None, 'Belgium'),
#  ('Brazil', 'Brazil'),
#  ('Canada', 'Canada'),
#  ('Denmark', 'Denmark'),
#  ('Finland', 'Finland'),
#  ('France', 'France'),
#  ('Germany', 'Germany'),
#  (None, 'Ireland'),
#  ('Italy', 'Italy'),
#  ('Japan', None),
#  (None, 'Mexico'),
#  ('Netherlands', None),
#  ('Norway', 'Norway'),
#  (None, 'Poland'),
#  (None, 'Portugal'),
#  ('Singapore', None),
#  ('Spain', 'Spain'),
#  ('Sweden', 'Sweden'),
#  (None, 'Switzerland'),
#  ('UK', 'UK'),
#  ('USA', 'USA'),
#  (None, 'Venezuela')]

# %% [markdown]
# ## M54. Count the number of suppliers and customers by country

# %%
# %%sql
# ; WITH SupplierCountries AS(
#     SELECT Country, Total = COUNT(*) FROM Suppliers GROUP BY Country
# ), CustomerCountries AS(
#     SELECT Country, Total = COUNT(*) FROM Customers GROUP BY Country
# )
#
# SELECT Country = ISNULL(SupplierCountries.Country, CustomerCountries.Country),
#     TotalSuppliers = ISNULL(SupplierCountries.Total, 0),
#     TotalCustomers = ISNULL(CustomerCountries.Total, 0)
# FROM SupplierCountries
# FULL OUTER JOIN CustomerCountries ON CustomerCountries.Country = SupplierCountries.Country
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [('Argentina', 0, 3),
#  ('Australia', 2, 0),
#  ('Austria', 0, 2),
#  ('Belgium', 0, 2),
#  ('Brazil', 1, 9),
#  ('Canada', 2, 3),
#  ('Denmark', 1, 2),
#  ('Finland', 1, 2),
#  ('France', 3, 11),
#  ('Germany', 3, 11),
#  ('Ireland', 0, 1),
#  ('Italy', 2, 3),
#  ('Japan', 2, 0),
#  ('Mexico', 0, 5),
#  ('Netherlands', 1, 0),
#  ('Norway', 1, 1),
#  ('Poland', 0, 1),
#  ('Portugal', 0, 2),
#  ('Singapore', 1, 0),
#  ('Spain', 1, 5),
#  ('Sweden', 2, 2),
#  ('Switzerland', 0, 2),
#  ('UK', 2, 7),
#  ('USA', 4, 13),
#  ('Venezuela', 0, 4)]

# %% [markdown]
# ## M55. First order in each country

# %%
# %%sql
# ; WITH OrdersByCountry AS(
#     SELECT ShipCountry, CustomerID, OrderID, OrderDate = CONVERT(DATE, OrderDate),
#         RowNumberPerCountry = Row_Number() over (Partition by ShipCountry Order by ShipCountry, OrderID)
#     FROM Orders
# )
#
# SELECT ShipCountry, CustomerID, OrderID, OrderDate
# FROM OrdersByCountry
# WHERE RowNumberPerCountry = 1 --<<<
# ORDER BY ShipCountry
# Out:
#  * mssql+pyodbc://sa:***@DESKTOP-NJ3QO6I:1433/NorthWind2016?driver=ODBC Driver 13 for SQL Server
# Done.
# Done.
# [('Argentina', 'OCEAN', 10409, datetime.date(2015, 1, 9)),
#  ('Austria', 'ERNSH', 10258, datetime.date(2014, 7, 17)),
#  ('Belgium', 'SUPRD', 10252, datetime.date(2014, 7, 9)),
#  ('Brazil', 'HANAR', 10250, datetime.date(2014, 7, 8)),
#  ('Canada', 'MEREP', 10332, datetime.date(2014, 10, 17)),
#  ('Denmark', 'SIMOB', 10341, datetime.date(2014, 10, 29)),
#  ('Finland', 'WARTH', 10266, datetime.date(2014, 7, 26)),
#  ('France', 'VINET', 10248, datetime.date(2014, 7, 4)),
#  ('Germany', 'TOMSP', 10249, datetime.date(2014, 7, 5)),
#  ('Ireland', 'HUNGO', 10298, datetime.date(2014, 9, 5)),
#  ('Italy', 'MAGAA', 10275, datetime.date(2014, 8, 7)),
#  ('Mexico', 'CENTC', 10259, datetime.date(2014, 7, 18)),
#  ('Norway', 'SANTG', 10387, datetime.date(2014, 12, 18)),
#  ('Poland', 'WOLZA', 10374, datetime.date(2014, 12, 5)),
# ...

# %% [markdown]
# ## M56. Show customers who have ever made more than 1 order in a 5-day period.

# %%
# %%sql
# SELECT InitialOrder.Customer, InitialOrderID = InitialOrder.OrderID,
#     InitialOrderDate = CONVERT(DATE, InitialOrder.OrderDate),
#     NextOrderID = NextOrder.OrderID,
#     NextOrderDate = CONVERT(DATE, NextOrder.OrderDate),
#     DaysBetween = DATEDIFF(DD, InitialOrder.OrderDate, NextOrder.OrderDate)
# FROM Orders InitialOrder JOIN Orders NextOrder ON InitialOrder.CustomerID = NextOrder.CustomerID
# WHERE InitialOrder.OrderID < NextOrder.OrderID AND Datediff(DD, InitialOrder.OrderDate, NextOrder.OrderDate) <= 5
# ORDER BY InitialOrder.CustomerID, InitiallOrder.OrderID

# %% [markdown]
# ## M57. Aontertive method (continued)

# %%
# %%sql
# ; WITH NextOrderDate AS(
#     SELECT CustomerID, OrderDate = CONVERT(DATE, OrderDate),
#         NextOrderDate = CONVERT(DATE, LEAD(OrderDate, 1) OVER (PARTITION BY CustomerID ORDER BY CustomerID, OrderDate))
#     FROM Orders
# )
# SELECT CustomerID, OrderDate, NextOrderDate, DaysBetweenOrders = DateDiff(DD, OrderDate, NextOrderDate)
# FROM NextOrderDate
# WHERE DateDiff(DD, OrderDate, NextOrderDate) <= 5
